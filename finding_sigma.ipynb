# %%
import skimage.io
import skimage.restoration
import matplotlib as plt

# %%
img = skimage.io.imread("Yes_RIPL.png")

# %%
sigma_est = skimage.restoration.estimate_sigma(skimage.img_as_float(img))
# Out:
# /Users/donnahooshmand/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: image is size 4 on the last axis, but multichannel is False.  If this is a color image, please set multichannel to True for proper noise estimation.
#   """Entry point for launching an IPython kernel.

# %%
sigma_est
# Out:
# 0.00012847525520925533

# %%
sigma_est = skimage.restoration.estimate_sigma(img)
# Out:
# /Users/donnahooshmand/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: image is size 4 on the last axis, but multichannel is False.  If this is a color image, please set multichannel to True for proper noise estimation.
#   """Entry point for launching an IPython kernel.

# %%
sigma_est
# Out:
# 0.03276119007835992

# %%
skimage.io.imshow(img)

# %%
plt.pyplot.show()
