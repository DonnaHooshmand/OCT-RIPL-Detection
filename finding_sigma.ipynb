# %%
import skimage.io
import skimage.restoration
import matplotlib as plt

# %%
img = skimage.io.imread("Yes_RIPL.jpg")

# %%
sigma_est = skimage.restoration.estimate_sigma(skimage.img_as_float(img))
# Out:
# /Users/donnahooshmand/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: image is size 3 on the last axis, but multichannel is False.  If this is a color image, please set multichannel to True for proper noise estimation.
#   """Entry point for launching an IPython kernel.

# %%
sigma_est
# Out:
# 4.822321638706807e-19

# %%
sigma_est = skimage.restoration.estimate_sigma(img)
# Out:
# /Users/donnahooshmand/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: image is size 3 on the last axis, but multichannel is False.  If this is a color image, please set multichannel to True for proper noise estimation.
#   """Entry point for launching an IPython kernel.

# %%
sigma_est
# Out:
# 1.2345143395089425e-16

# %%
skimage.io.imshow(img)

# %%
plt.pyplot.show()
